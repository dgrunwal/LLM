# %%
import openai

# %%
client = openai.OpenAI(api_key= "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")

# %%
response = client.images.generate(
    model = 'dall-e-3',
    prompt="A futuristic lagos nigeria skyline at sunset with flying cars",
    size = '1024x1024',
    quality="standard",
    n=1
)

# %%
image_url = response.data[0].url
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-r8lCil96SUtdlZaApdNrh5MI/user-DHU2Hll936hZPEfvJqKbZrbC/img-q9enp8l1UJ9oLYaVXX6UvtPj.png?st=2025-05-02T10%3A10%3A25Z&se=2025-05-02T12%3A10%3A25Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-01T23%3A24%3A43Z&ske=2025-05-02T23%3A24%3A43Z&sks=b&skv=2024-08-04&sig=lSJA42TCJorgUMAPcQ6bEmlP3Bv3wkYF1poU59XcBj0%3D'

# %%
response = client.images.generate(
    model = 'dall-e-3',
    prompt="A cartoon image depicting navigating the ai ecosystem",
    size = '1024x1024',
    quality="standard",
    n=1
)

# %%
image_url = response.data[0].url
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-r8lCil96SUtdlZaApdNrh5MI/user-DHU2Hll936hZPEfvJqKbZrbC/img-Ed6gezFEf6lYzPtoaB45dDBT.png?st=2025-05-02T10%3A12%3A36Z&se=2025-05-02T12%3A12%3A36Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-01T23%3A04%3A42Z&ske=2025-05-02T23%3A04%3A42Z&sks=b&skv=2024-08-04&sig=MOWD3gc2BWAMcn2cnjP0GZX1vWb7Im%2B0sd7ni2VE9EU%3D'

# %%
from IPython.display import Image
Image(url=image_url)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-r8lCil96SUtdlZaApdNrh5MI/user-DHU2Hll936hZPEfvJqKbZrbC/img-Ed6gezFEf6lYzPtoaB45dDBT.png?st=2025-05-02T10%3A12%3A36Z&se=2025-05-02T12%3A12%3A36Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-01T23%3A04%3A42Z&ske=2025-05-02T23%3A04%3A42Z&sks=b&skv=2024-08-04&sig=MOWD3gc2BWAMcn2cnjP0GZX1vWb7Im%2B0sd7ni2VE9EU%3D"/>
